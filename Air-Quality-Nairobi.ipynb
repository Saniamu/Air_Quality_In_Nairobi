# %% [markdown]
# # Air Quality in Nairobi — Time Series Analysis
# ## Project Overview
# This project analyses PM2.5 air quality data from Nairobi using an ARIMA model.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("All packages loaded successfully✅")
# Out:
# All packages loaded successfully✅
